# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
plt.figure()

for seed in range(0,25):
    data = pd.read_csv("data/%02d.txt" % seed, header=0, delimiter=" ")

    plt.plot(data["t"],data["H"])
    plt.plot(data["t"],data["P"])
